# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3082, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.015323
# Nearest to on: suing, van, turin, refracted, wiley, inherit, contending, lula,
# Nearest to american: showered, x, sasl, moldavia, starter, residential, mediterranean, pile,
# Nearest to can: christological, key, tiraspol, randomly, foyle, encrypting, skipping, jesse,
# Nearest to while: megas, andorran, kicker, warships, shakyamuni, lavos, awake, pommel,
# Nearest to of: linea, rapper, longship, trailed, freedman, clutches, obituary, unrepentant,
# Nearest to people: dishonesty, propositions, trending, pascha, continually, advertise, fundamentals, hylas,
# Nearest to a: jabberwocky, berlin, flirting, croix, daria, retrospectively, ambience, decaying,
# Nearest to four: odi, fossilization, koran, resolving, ordaining, omar, newsreel, xiaoping,
# Nearest to to: merchant, induced, triangles, vestments, tambourine, christianum, dives, caledonian,
# Nearest to their: fonts, esteem, telegraphs, agora, dragoon, eucalyptus, vardar, butane,
# Nearest to this: occultism, theists, displacing, michelle, rta, thulsa, rickshaw, faure,
# Nearest to will: douglas, liquidated, inflected, dirk, chalcedon, processing, lysis, choirs,
# Nearest to between: absorbs, drava, contracts, tucum, muentzer, cp, gendered, nucleotide,
# Nearest to world: qatar, moncton, singular, cam, loot, euphoria, impression, abstracts,
# Nearest to some: synth, aquarium, anode, negated, inflate, spectroscopic, arnauld, clip,
# Nearest to its: francisco, turbine, correspondingly, kenner, capability, permission, erebus, olympics,
# Average loss at step 2000: 4.369297
# Average loss at step 4000: 3.867409
# Average loss at step 6000: 3.791910
# Average loss at step 8000: 3.687212
# Average loss at step 10000: 3.619387
# Nearest to on: in, at, mustard, wiley, dune, contending, of, by,
# Nearest to american: rinzai, starter, pacts, basslines, sravaka, sasl, showered, bevan,
# Nearest to can: must, may, would, tiraspol, key, should, peachtree, lott,
# Nearest to while: tang, iud, megas, lavos, kicker, awake, bri, danielle,
# Nearest to of: in, for, reestablished, same, and, obituary, freedman, mitt,
# Nearest to people: trending, propositions, taiko, applesoft, supplementary, conical, dishonesty, hostile,
# Nearest to a: the, colliding, his, strident, analysed, this, nationalism, indicative,
# Nearest to four: six, three, eight, five, seven, two, nine, zero,
# Nearest to to: bras, not, visuals, lenten, haskalah, into, blacks, mclachlan,
# Nearest to their: his, its, the, preoccupations, emotionally, some, walt, quarreled,
# Nearest to this: it, which, the, mkultra, that, his, pre, a,
# Nearest to will: would, beauties, astrological, may, should, frantz, lysis, douglas,
# Nearest to between: with, drava, digital, protege, smoothing, gurmukhi, nikos, headless,
# Nearest to world: qatar, euphoria, moncton, impression, cam, loot, mcclellan, atahualpa,
# Nearest to some: many, antidisestablishmentarianism, yoannis, their, spectroscopic, charset, aegon, gehenna,
# Nearest to its: the, their, his, erebus, francisco, eurocents, hazardous, extraneous,
# Average loss at step 12000: 3.603934
# Average loss at step 14000: 3.570016
# Average loss at step 16000: 3.409694
# Average loss at step 18000: 3.454706
# Average loss at step 20000: 3.544428
# Nearest to on: in, at, wiley, upon, klaproth, for, needlessly, aristotelian,
# Nearest to american: australian, british, english, starter, french, bevan, basslines, prisoners,
# Nearest to can: may, would, must, could, will, should, lott, cannot,
# Nearest to while: tang, iud, under, ectopic, without, bri, locked, mandelstam,
# Nearest to of: unrepentant, for, confront, nyc, cadmium, bankrupt, freedman, marianne,
# Nearest to people: propositions, trending, supplementary, hostile, those, carboxyl, historians, omitted,
# Nearest to a: the, idolatry, nationalism, decolonisation, habsburgs, bregovi, indicative, this,
# Nearest to four: three, seven, six, eight, five, two, nine, zero,
# Nearest to to: will, electorates, visuals, could, bras, mclachlan, not, lenten,
# Nearest to their: its, his, the, some, dissimilar, her, any, many,
# Nearest to this: it, which, the, he, regionally, bis, a, that,
# Nearest to will: would, may, can, could, should, to, must, beauties,
# Nearest to between: with, in, from, drava, against, celia, headless, gurmukhi,
# Nearest to world: qatar, cam, moncton, remaining, kuo, apollo, ali, loot,
# Nearest to some: many, all, these, their, other, several, yoannis, appropriating,
# Nearest to its: their, the, his, erebus, eurocents, nirvana, some, faltering,
# Average loss at step 22000: 3.500946
# Average loss at step 24000: 3.489872
# Average loss at step 26000: 3.479195
# Average loss at step 28000: 3.479283
# Average loss at step 30000: 3.508317
# Nearest to on: upon, in, through, into, at, from, during, between,
# Nearest to american: australian, british, french, canadian, basslines, english, and, bevan,
# Nearest to can: may, would, will, could, must, should, cannot, might,
# Nearest to while: when, is, debtor, qe, sacs, bauhaus, without, strickland,
# Nearest to of: in, from, confront, marianne, throughout, and, beijing, ruthlessly,
# Nearest to people: propositions, historians, trending, descended, chemists, countries, those, tutte,
# Nearest to a: indicative, the, any, violating, idolatry, whetstone, buckyballs, known,
# Nearest to four: five, three, six, seven, eight, nine, two, zero,
# Nearest to to: would, can, will, pigpen, could, not, might, gx,
# Nearest to their: his, its, the, her, some, dissimilar, these, our,
# Nearest to this: which, it, that, entomology, any, there, imperfections, apteryx,
# Nearest to will: would, can, may, could, should, must, might, cannot,
# Nearest to between: with, from, against, on, in, drava, gurmukhi, absorbs,
# Nearest to world: loot, qatar, moncton, remaining, cam, impression, atahualpa, kuo,
# Nearest to some: many, these, all, several, most, their, appropriating, other,
# Nearest to its: their, his, the, achaemenid, partitioning, eurocents, nirvana, richmond,
# Average loss at step 32000: 3.501883
# Average loss at step 34000: 3.496869
# Average loss at step 36000: 3.450903
# Average loss at step 38000: 3.302301
# Average loss at step 40000: 3.432985
# Nearest to on: upon, at, in, during, between, through, wiley, into,
# Nearest to american: australian, french, british, german, basslines, english, canadian, russian,
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to while: when, although, fy, until, before, without, qe, motorised,
# Nearest to of: in, confront, from, for, freedman, marianne, reestablished, reprising,
# Nearest to people: descended, historians, didier, arf, man, trending, those, rags,
# Nearest to a: the, another, foodborne, any, flickering, or, idolatry, buckyballs,
# Nearest to four: six, three, eight, five, seven, two, nine, zero,
# Nearest to to: can, will, could, visuals, would, radial, electorates, in,
# Nearest to their: its, his, her, the, dissimilar, your, both, any,
# Nearest to this: which, it, that, the, another, any, alcor, he,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to between: from, with, on, drava, in, against, among, invitational,
# Nearest to world: mcclellan, loot, kuo, u, moncton, lollard, remaining, apollo,
# Nearest to some: many, these, several, most, any, various, all, both,
# Nearest to its: their, his, the, her, any, eurocents, greasy, nirvana,
# Average loss at step 42000: 3.432571
# Average loss at step 44000: 3.458271
# Average loss at step 46000: 3.452307
# Average loss at step 48000: 3.354819
# Average loss at step 50000: 3.382271
# Nearest to on: upon, through, in, needlessly, wiley, enrichment, dispossessed, for,
# Nearest to american: australian, french, english, german, canadian, basslines, russian, british,
# Nearest to can: will, may, would, could, must, should, might, cannot,
# Nearest to while: when, although, before, but, where, though, after, if,
# Nearest to of: and, in, autonomously, marianne, including, throughout, confront, episcopal,
# Nearest to people: men, jews, historians, trending, ascorbic, supplementary, didier, arf,
# Nearest to a: another, the, indicative, nationalism, abreast, habsburgs, violating, any,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to to: would, could, might, can, lions, veganism, brahman, will,
# Nearest to their: its, his, her, the, both, our, your, some,
# Nearest to this: which, the, it, that, cordilleras, alcor, he, another,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to between: with, against, drava, from, among, through, in, gurmukhi,
# Nearest to world: lollard, mcclellan, largest, loot, generation, kuo, moncton, saw,
# Nearest to some: many, these, several, various, most, any, both, all,
# Nearest to its: their, his, the, her, eurocents, achaemenid, lighting, galesburg,
# Average loss at step 52000: 3.440029
# Average loss at step 54000: 3.424108
# Average loss at step 56000: 3.438058
# Average loss at step 58000: 3.394410
# Average loss at step 60000: 3.398317
# Nearest to on: upon, through, in, needlessly, aristotelian, enrichment, klaproth, catamarans,
# Nearest to american: australian, british, german, english, french, russian, basslines, irish,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to while: although, when, before, after, without, though, sacs, were,
# Nearest to of: in, including, hbf, for, autonomously, freedman, exact, ccds,
# Nearest to people: historians, men, jews, descended, schliemann, players, arf, supplementary,
# Nearest to a: another, the, ivan, any, nationalism, foodborne, habsburgs, indicative,
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to to: would, will, lenten, brahman, could, must, for, can,
# Nearest to their: its, his, her, the, our, dissimilar, some, my,
# Nearest to this: which, it, that, imposed, there, the, however, entomology,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to between: with, among, into, through, drava, from, within, greyhound,
# Nearest to world: largest, bpp, mcclellan, vietnam, swore, kuo, tart, saw,
# Nearest to some: many, several, these, most, all, various, any, the,
# Nearest to its: their, his, the, her, eurocents, nirvana, erebus, humiliating,
# Average loss at step 62000: 3.244753
# Average loss at step 64000: 3.254654
# Average loss at step 66000: 3.408080
# Average loss at step 68000: 3.391593
# Average loss at step 70000: 3.361967
# Nearest to on: upon, through, in, needlessly, buyer, enrichment, within, at,
# Nearest to american: australian, british, english, canadian, german, basslines, cornish, french,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to while: although, when, though, before, however, and, after, but,
# Nearest to of: including, autonomously, include, for, freedman, like, in, ccds,
# Nearest to people: historians, men, players, descended, students, rags, children, arf,
# Nearest to a: another, the, indicative, any, foodborne, enough, ivan, celeste,
# Nearest to four: seven, six, five, three, eight, two, zero, nine,
# Nearest to to: will, can, would, coagulation, distressed, lenten, cannot, tendons,
# Nearest to their: its, his, her, the, your, our, my, dissimilar,
# Nearest to this: it, which, another, the, that, there, tori, entomology,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to between: with, among, from, within, into, through, in, drava,
# Nearest to world: largest, bpp, tart, u, vietnam, unmixed, visionary, argentines,
# Nearest to some: many, several, these, all, most, various, any, both,
# Nearest to its: their, his, the, her, nirvana, my, eurocents, dissimilar,
# Average loss at step 72000: 3.374410
# Average loss at step 74000: 3.351581
# Average loss at step 76000: 3.317686
# Average loss at step 78000: 3.351716
# Average loss at step 80000: 3.381003
# Nearest to on: upon, through, in, during, needlessly, buyer, sojourn, dispossessed,
# Nearest to american: australian, british, canadian, german, international, basslines, italian, english,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to while: although, though, when, after, before, despite, but, during,
# Nearest to of: autonomously, including, marianne, entire, makeover, in, paulsen, determinant,
# Nearest to people: historians, men, children, students, players, descended, individuals, women,
# Nearest to a: another, the, indicative, abreast, violating, every, decolonisation, any,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to to: will, would, should, lions, lenten, distressed, visuals, must,
# Nearest to their: its, his, her, your, our, the, my, both,
# Nearest to this: which, it, the, underarm, another, that, there, some,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to between: among, within, with, drava, through, protege, invitational, from,
# Nearest to world: u, largest, vietnam, unmixed, endymion, argentines, swore, bpp,
# Nearest to some: many, several, these, most, any, various, both, appropriating,
# Nearest to its: their, his, the, her, your, my, our, nirvana,
# Average loss at step 82000: 3.404393
# Average loss at step 84000: 3.411755
# Average loss at step 86000: 3.387793
# Average loss at step 88000: 3.358120
# Average loss at step 90000: 3.363675
# Nearest to on: upon, through, under, against, sojourn, in, honourable, enrichment,
# Nearest to american: british, australian, canadian, english, italian, german, cornish, basslines,
# Nearest to can: must, could, may, will, would, should, might, cannot,
# Nearest to while: although, when, though, after, during, before, but, until,
# Nearest to of: including, for, autonomously, hbf, marianne, adage, in, include,
# Nearest to people: historians, children, men, students, players, women, individuals, schliemann,
# Nearest to a: another, the, ivan, any, goliath, buckyballs, every, decolonisation,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to to: visuals, would, brahman, philanthropy, will, induced, crafting, lenten,
# Nearest to their: its, his, her, your, our, my, the, dissimilar,
# Nearest to this: it, which, the, another, some, predatory, underarm, entomology,
# Nearest to will: would, could, can, must, may, might, should, cannot,
# Nearest to between: with, within, among, in, from, under, during, into,
# Nearest to world: nijmegen, vietnam, swore, unmixed, basis, bpp, u, behest,
# Nearest to some: many, several, these, all, any, most, both, various,
# Nearest to its: their, his, her, the, your, my, nirvana, our,
# Average loss at step 92000: 3.402164
# Average loss at step 94000: 3.257627
# Average loss at step 96000: 3.356431
# Average loss at step 98000: 3.247341
# Average loss at step 100000: 3.358540
# Nearest to on: upon, through, in, at, needlessly, enrichment, around, pickle,
# Nearest to american: british, australian, canadian, italian, french, basslines, sravaka, english,
# Nearest to can: may, could, must, will, would, should, might, cannot,
# Nearest to while: although, when, though, but, before, and, after, during,
# Nearest to of: including, autonomously, in, aiki, whose, reestablished, magnon, severance,
# Nearest to people: historians, children, men, students, individuals, women, players, schliemann,
# Nearest to a: another, any, the, indicative, decolonisation, saloons, abreast, foodborne,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to to: will, should, could, can, would, visuals, must, lenten,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to this: which, it, another, he, what, there, peerless, some,
# Nearest to will: would, can, could, must, may, might, should, cannot,
# Nearest to between: with, among, within, chem, invitational, hamster, through, disturbance,
# Nearest to world: u, vietnam, tart, swore, endymion, behest, hipper, unless,
# Nearest to some: many, several, these, any, all, various, most, certain,
# Nearest to its: their, his, galesburg, the, your, nirvana, her, steal,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, context_window):
    global data_index
    batch = np.ndarray(shape=(batch_size, 2 * context_window), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * context_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        batch[i, :] = [token for idx, token in enumerate(buffer) if idx != context_window] 
        labels[i, 0] = buffer[context_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for context_window in [2, 4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = {}'.format(context_window))
    for i in range(8):
        print('    ', reverse_dictionary[labels[i, 0]], '<-',[reverse_dictionary[bi] for bi in batch[i, :]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with context_window = 2
#      as <- ['anarchism', 'originated', 'a', 'term']
#      a <- ['originated', 'as', 'term', 'of']
#      term <- ['as', 'a', 'of', 'abuse']
#      of <- ['a', 'term', 'abuse', 'first']
#      abuse <- ['term', 'of', 'first', 'used']
#      first <- ['of', 'abuse', 'used', 'against']
#      used <- ['abuse', 'first', 'against', 'early']
#      against <- ['first', 'used', 'early', 'working']
#
# with context_window = 4
#      term <- ['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used']
#      of <- ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against']
#      abuse <- ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early']
#      first <- ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']
#      used <- ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class']
#      against <- ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals']
#      early <- ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including']
#      working <- ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 4 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
  
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * context_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                           stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights,
                                   biases=softmax_biases,
                                   inputs=tf.reduce_sum(embed, 1),
                                   labels=train_labels,
                                   num_sampled=num_sampled,
                                   num_classes=vocabulary_size))
    
  
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 200001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, context_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.826856
# Nearest to i: material, evil, microarchitecture, reinventing, cautions, associating, dualities, hagar,
# Nearest to may: thant, frequent, illusions, londoners, repugnant, medes, multipart, medicaid,
# Nearest to they: middletown, syncretism, palm, rejects, strangely, jagan, koan, babi,
# Nearest to and: calculate, ricans, stall, contract, hearn, minaret, grossman, kryptonians,
# Nearest to between: rrna, abolished, fables, pontius, partial, cosmo, cynic, westernmost,
# Nearest to use: habakkuk, unequalled, neuronal, sligo, fritz, coinage, ite, walks,
# Nearest to of: ovulation, shipper, mokhehle, advancing, dean, sextus, ranged, laziness,
# Nearest to more: socialization, aznar, stadt, repression, buck, overture, besieged, ammonia,
# Nearest to for: redactor, nielsen, merciful, xp, xxix, binds, hoffer, blume,
# Nearest to nine: prostitution, albans, were, lozada, legislators, revitalized, gammu, maris,
# Nearest to such: sixty, grub, schneider, frequency, architecturally, roshan, ciudad, resignations,
# Nearest to five: animation, painstaking, inlaid, admin, wollstonecraft, knife, desi, cinemas,
# Nearest to with: willughby, brisk, above, pluralist, fairies, nationalists, tolbert, accesses,
# Nearest to that: bunyan, santa, veritas, acquire, encompasses, acoustic, drafts, helens,
# Nearest to been: palestine, encountered, axons, fifteen, thulsa, covalent, chariots, enthalpy,
# Nearest to was: loot, gordian, forma, karami, taxi, arianism, prepubescent, ponte,
# Average loss at step 2000: 6.995975
# Average loss at step 4000: 5.265292
# Average loss at step 6000: 4.904139
# Average loss at step 8000: 4.686014
# Average loss at step 10000: 4.533283
# Nearest to i: ii, wanting, neapolitan, indochina, standardizing, wharton, hippolytus, batgirl,
# Nearest to may: can, would, could, should, might, will, must, to,
# Nearest to they: acetic, quesada, interrogations, masochism, tei, toulouse, disruption, ethno,
# Nearest to and: with, while, hanged, uriah, trotskyism, commandments, mites, byers,
# Nearest to between: pondering, since, contextual, misdemeanor, symptoms, mok, into, shalmaneser,
# Nearest to use: rearguard, area, go, subscripts, tricyclic, fundamentally, dystrophy, devourer,
# Nearest to of: for, against, daro, ecologist, on, aerosmith, marquee, meier,
# Nearest to more: less, rather, declined, cu, baekje, heft, gerson, better,
# Nearest to for: of, aeronautics, kerman, in, carat, reserves, herders, batsman,
# Nearest to nine: eight, dyadic, elisa, six, misrepresented, configure, seven, rfc,
# Nearest to such: well, known, disability, diffusion, ayub, seen, tile, affluence,
# Nearest to five: four, lombok, three, sprache, zero, sticky, two, moonshine,
# Nearest to with: within, and, in, fs, entrails, electrophysiology, loose, psychoanalytic,
# Nearest to that: when, which, also, if, chimpanzee, what, cuckoo, because,
# Nearest to been: become, loire, flees, uncountable, opengl, aristocrat, optimum, stormed,
# Nearest to was: is, were, became, are, trousers, anthology, electroconvulsive, microorganism,
# Average loss at step 12000: 4.461712
# Average loss at step 14000: 4.413494
# Average loss at step 16000: 4.247833
# Average loss at step 18000: 4.277028
# Average loss at step 20000: 4.165521
# Nearest to i: we, jagger, bsi, garz, jeep, dogme, columbians, hallelujah,
# Nearest to may: can, will, might, would, could, must, should, cannot,
# Nearest to they: hahn, satie, overheat, we, variability, duquette, front, potemkin,
# Nearest to and: but, flinders, undermines, lizzie, alamo, or, partridge, fret,
# Nearest to between: pondering, disobedience, jump, weser, mok, suras, ru, pave,
# Nearest to use: provide, initialized, refer, souls, everett, forms, schoolhouse, due,
# Nearest to of: following, in, same, during, aerosmith, among, throughout, for,
# Nearest to more: less, rather, larger, better, most, greater, smaller, higher,
# Nearest to for: ltv, minimization, of, ago, nigel, shelley, oghuz, seif,
# Nearest to nine: th, eight, everest, ally, malaria, marija, imap, clapping,
# Nearest to such: well, known, far, referred, seen, mandel, described, hoyt,
# Nearest to five: three, referent, zero, two, kingpin, seven, vehicular, venerated,
# Nearest to with: from, slower, in, adversely, masoretic, audubon, asser, roberto,
# Nearest to that: if, whose, whether, where, pashtun, which, this, although,
# Nearest to been: become, no, come, grown, hevelius, vives, little, dms,
# Nearest to was: is, were, became, are, had, came, began, remained,
# Average loss at step 22000: 3.898915
# Average loss at step 24000: 3.682417
# Average loss at step 26000: 3.892509
# Average loss at step 28000: 3.883415
# Average loss at step 30000: 3.933125
# Nearest to i: floors, strand, nintendo, who, septicemic, vail, you, lamanites,
# Nearest to may: can, must, might, should, could, would, will, cannot,
# Nearest to they: we, innocents, caravan, invite, irreducible, wic, traditionally, chippewa,
# Nearest to and: lets, equipping, thrive, messe, while, amistad, marat, clippings,
# Nearest to between: throughout, pondering, cartel, among, shopkeeper, with, within, isu,
# Nearest to use: form, refer, reverses, plate, amount, guardianship, tojo, suzy,
# Nearest to of: in, throughout, same, next, locksmithing, equipping, penetrates, aerosmith,
# Nearest to more: less, rather, better, higher, larger, greater, most, smaller,
# Nearest to for: proportionate, spent, dbms, modelling, dissatisfaction, serie, freshman, ugle,
# Nearest to nine: eight, seven, six, presupposes, illustration, enumerative, footnotes, worthies,
# Nearest to such: well, far, known, possible, seen, result, described, overtraining,
# Nearest to five: eight, recalcitrant, three, four, seven, two, zero, six,
# Nearest to with: hurrian, despite, as, involving, between, bioterrorism, snuck, including,
# Nearest to that: which, whether, however, who, if, sometimes, fairly, where,
# Nearest to been: become, remained, grown, dms, no, portable, ashcroft, come,
# Nearest to was: is, were, are, makes, became, had, becomes, exists,
# Average loss at step 32000: 3.924998
# Average loss at step 34000: 3.702067
# Average loss at step 36000: 3.879609
# Average loss at step 38000: 3.923194
# Average loss at step 40000: 3.887118
# Nearest to i: you, nicholls, sato, kangaroos, mehrgarh, g, kushner, sephardim,
# Nearest to may: can, might, will, must, should, could, would, cannot,
# Nearest to they: we, these, corrupt, evidently, seminary, you, some, there,
# Nearest to and: or, pomona, etc, while, mathew, atiyah, augmenting, lans,
# Nearest to between: with, nozzles, within, through, around, frontline, from, in,
# Nearest to use: refer, perform, produce, understand, mean, serve, clergymen, return,
# Nearest to of: in, following, locksmithing, within, brodsky, discouraging, rockin, for,
# Nearest to more: less, rather, larger, faster, better, most, steinbeck, relatively,
# Nearest to for: during, after, vrml, against, gravely, ats, spent, repellent,
# Nearest to nine: eight, seven, erdrich, enumerative, elaborates, six, melds, stifle,
# Nearest to such: well, far, regarded, known, seen, described, referred, jumo,
# Nearest to five: four, richer, ancona, ibis, hepworth, borax, natalia, three,
# Nearest to with: between, without, as, berber, despite, balcony, through, among,
# Nearest to that: which, how, this, whether, where, if, because, therefore,
# Nearest to been: become, grown, occurred, begun, remained, come, bouchard, ketchup,
# Nearest to was: is, were, are, makes, became, had, becomes, being,
# Average loss at step 42000: 3.553221
# Average loss at step 44000: 3.708176
# Average loss at step 46000: 3.646519
# Average loss at step 48000: 3.781291
# Average loss at step 50000: 3.613585
# Nearest to i: g, tzu, crist, ii, fittest, hooves, rods, you,
# Nearest to may: can, could, would, should, must, will, might, cannot,
# Nearest to they: these, we, lcd, palatable, reinforcing, frodo, boulders, dlr,
# Nearest to and: or, but, who, with, cruising, flinders, marguerite, while,
# Nearest to between: with, within, in, through, throughout, nozzles, unsolved, bodhisattvas,
# Nearest to use: dimmu, practice, clergymen, amount, definition, coprime, units, conductivity,
# Nearest to of: throughout, in, for, like, among, locksmithing, gives, during,
# Nearest to more: less, rather, better, faster, smaller, larger, greater, higher,
# Nearest to for: after, against, of, during, hrvatska, over, following, beth,
# Nearest to nine: eight, seven, refitted, presupposes, iers, bcl, deuce, ethiopians,
# Nearest to such: well, far, opposed, regarded, known, seen, interpreted, referred,
# Nearest to five: nicaea, three, four, seven, patois, sardar, intervenes, pearls,
# Nearest to with: between, by, and, from, thessalonians, had, among, into,
# Nearest to that: which, where, when, who, normally, never, if, this,
# Nearest to been: become, come, begun, existed, grown, occurred, evolved, fallen,
# Nearest to was: is, were, became, are, makes, exists, becomes, had,
# Average loss at step 52000: 3.743275
# Average loss at step 54000: 3.691608
# Average loss at step 56000: 3.636492
# Average loss at step 58000: 3.579699
# Average loss at step 60000: 3.553850
# Nearest to i: g, ii, we, lintel, unprotected, methyl, battlefields, stephen,
# Nearest to may: can, should, would, could, must, might, cannot, will,
# Nearest to they: we, he, you, wilhelmina, some, these, nicotine, penultimate,
# Nearest to and: but, or, while, who, tenacious, however, sarasota, finishes,
# Nearest to between: with, unacceptably, within, then, over, pondering, throughout, in,
# Nearest to use: practice, used, using, interfere, introduction, attend, difranco, refers,
# Nearest to of: throughout, following, in, nou, aerosmith, within, on, gives,
# Nearest to more: rather, less, greater, larger, better, faster, longer, fewer,
# Nearest to for: after, within, without, before, through, toward, throughout, vrml,
# Nearest to nine: eight, seven, six, four, five, nde, births, zero,
# Nearest to such: well, far, regarded, classified, known, described, seen, referred,
# Nearest to five: four, seven, six, three, eight, nine, condensate, auschwitz,
# Nearest to with: between, by, hurrian, untersuchungen, displeased, voronin, mould, unimpeded,
# Nearest to that: which, where, whether, what, this, if, unless, meanwhile,
# Nearest to been: become, come, grown, begun, fallen, existed, evolved, occurred,
# Nearest to was: is, became, were, are, remained, had, makes, exists,
# Average loss at step 62000: 3.509250
# Average loss at step 64000: 3.539325
# Average loss at step 66000: 3.560991
# Average loss at step 68000: 3.563860
# Average loss at step 70000: 3.548288
# Nearest to i: we, g, you, they, shoots, ii, unprotected, memorized,
# Nearest to may: can, should, could, might, must, will, would, cannot,
# Nearest to they: we, topical, i, there, you, tribunes, helena, mclean,
# Nearest to and: or, while, but, devouring, however, ogdoad, whereas, when,
# Nearest to between: with, pondering, concerning, within, both, from, unacceptably, appointments,
# Nearest to use: accusing, refer, grandparents, produce, manipulate, regard, drink, construction,
# Nearest to of: throughout, in, locksmithing, towards, following, aerosmith, hlich, without,
# Nearest to more: less, rather, better, larger, greater, faster, most, fairly,
# Nearest to for: without, yastrzemski, within, throughout, saw, announces, to, desegregation,
# Nearest to nine: eight, seven, six, four, himalaya, flips, equalization, minotaur,
# Nearest to such: well, far, described, regarded, seen, classified, viewed, soon,
# Nearest to five: four, seven, six, three, eight, zero, fifty, billion,
# Nearest to with: including, between, by, has, where, placate, despite, moat,
# Nearest to that: which, where, if, although, how, why, who, always,
# Nearest to been: become, begun, occurred, grown, evolved, fallen, existed, come,
# Nearest to was: is, became, were, are, had, becomes, remained, makes,
# Average loss at step 72000: 3.373492
# Average loss at step 74000: 3.538360
# Average loss at step 76000: 3.512627
# Average loss at step 78000: 3.497838
# Average loss at step 80000: 3.537503
# Nearest to i: g, we, ga, assailant, you, iii, battlefields, shrinks,
# Nearest to may: would, should, might, can, could, must, cannot, will,
# Nearest to they: we, he, she, you, traffickers, unlawful, gulch, frodo,
# Nearest to and: or, but, although, whereas, sybil, which, while, however,
# Nearest to between: through, into, with, concerning, within, hellish, hyperbolic, both,
# Nearest to use: refer, return, referred, cause, wear, attributed, kill, apply,
# Nearest to of: following, including, for, in, locksmithing, includes, among, without,
# Nearest to more: less, rather, faster, better, most, smaller, greater, larger,
# Nearest to for: before, after, over, during, without, following, gravely, later,
# Nearest to nine: eight, six, four, seven, edif, dated, culminated, konar,
# Nearest to such: well, far, regarded, known, classified, described, viewed, follows,
# Nearest to five: four, three, eight, topalov, two, zero, gimme, seven,
# Nearest to with: between, while, tagore, placate, voronin, featuring, rugrats, among,
# Nearest to that: which, where, when, what, if, whenever, how, why,
# Nearest to been: become, begun, existed, grown, occurred, come, fallen, evolved,
# Nearest to was: is, were, are, became, becomes, seems, makes, had,
# Average loss at step 82000: 3.444986
# Average loss at step 84000: 3.272022
# Average loss at step 86000: 3.474868
# Average loss at step 88000: 3.439052
# Average loss at step 90000: 3.475432
# Nearest to i: g, ii, we, you, battlefields, fascists, illusory, fucking,
# Nearest to may: would, can, might, will, could, should, must, cannot,
# Nearest to they: you, we, he, osman, these, scrabble, gianfranco, corrective,
# Nearest to and: or, while, kath, including, although, operands, whereas, but,
# Nearest to between: with, across, into, among, social, hellish, throughout, through,
# Nearest to use: addition, prefer, allow, refers, apply, used, referred, produce,
# Nearest to of: following, throughout, locksmithing, same, in, including, nou, among,
# Nearest to more: less, rather, faster, greater, larger, most, slower, better,
# Nearest to for: spent, ago, throughout, before, through, after, ipkf, by,
# Nearest to nine: eight, seven, six, edif, tianjin, booked, hippies, romain,
# Nearest to such: well, far, regarded, classified, seen, interpreted, opposed, viewed,
# Nearest to five: six, eight, four, three, seven, incited, zero, two,
# Nearest to with: between, despite, without, haba, featuring, including, everson, by,
# Nearest to that: which, where, if, how, unless, whether, why, although,
# Nearest to been: become, fallen, begun, grown, occurred, evolved, gone, existed,
# Nearest to was: is, became, were, are, becomes, exists, remains, includes,
# Average loss at step 92000: 3.490833
# Average loss at step 94000: 3.506519
# Average loss at step 96000: 3.456448
# Average loss at step 98000: 3.411323
# Average loss at step 100000: 3.447448
# Nearest to i: g, you, professionally, we, fucking, sutcliffe, fascists, ga,
# Nearest to may: can, should, might, would, could, will, cannot, must,
# Nearest to they: we, you, these, chippewa, others, people, caravan, reinventing,
# Nearest to and: or, but, etc, unlike, while, ati, tiu, though,
# Nearest to between: with, across, both, among, throughout, from, varela, in,
# Nearest to use: application, most, coinage, tabs, backfield, disclose, shellfish, introduce,
# Nearest to of: following, throughout, in, for, locksmithing, before, include, concerning,
# Nearest to more: less, rather, larger, greater, faster, fewer, better, stronger,
# Nearest to for: besides, before, of, after, when, zahir, why, ago,
# Nearest to nine: seven, eight, six, haig, himalaya, births, lsi, orgy,
# Nearest to such: well, described, regarded, follows, seen, interpreted, far, classified,
# Nearest to five: four, three, seven, eight, two, dac, fen, che,
# Nearest to with: between, by, including, thessalonians, via, representing, haba, hurrian,
# Nearest to that: which, where, this, why, what, currently, unless, how,
# Nearest to been: become, begun, fallen, grown, gone, evolved, occurred, survived,
# Nearest to was: is, were, became, are, becomes, remains, exists, makes,
# Average loss at step 102000: 3.401276
# Average loss at step 104000: 3.405642
# Average loss at step 106000: 3.392505
# Average loss at step 108000: 3.275862
# Average loss at step 110000: 3.362747
# Nearest to i: cramer, nhs, harmonization, you, farce, j, excel, battlefields,
# Nearest to may: can, should, would, could, must, might, will, cannot,
# Nearest to they: we, you, he, who, others, venizelos, some, attrition,
# Nearest to and: or, while, etc, but, however, whereas, although, shrewd,
# Nearest to between: across, over, throughout, within, through, with, into, varela,
# Nearest to use: allow, refer, understanding, return, usage, clergymen, apply, understand,
# Nearest to of: following, besides, above, among, represents, for, behind, in,
# Nearest to more: less, faster, rather, greater, larger, fewer, slower, better,
# Nearest to for: after, within, ago, before, besides, of, following, without,
# Nearest to nine: eight, seven, six, four, rigdon, slayer, polly, raum,
# Nearest to such: well, described, follows, viewed, opposed, regarded, classified, result,
# Nearest to five: four, six, three, zero, seven, eight, chapters, two,
# Nearest to with: between, by, petropavlovsk, everson, against, representing, through, safeties,
# Nearest to that: which, where, whose, unless, whether, what, who, whereas,
# Nearest to been: begun, fallen, survived, become, occurred, disappeared, existed, grown,
# Nearest to was: is, became, were, are, becomes, remains, had, has,
# Average loss at step 112000: 3.352364
# Average loss at step 114000: 3.278991
# Average loss at step 116000: 3.305750
# Average loss at step 118000: 3.324223
# Average loss at step 120000: 3.364890
# Nearest to i: ripe, we, cookbooks, patricians, quenched, hasbro, ii, sifre,
# Nearest to may: can, might, would, could, will, must, should, cannot,
# Nearest to they: we, others, people, counterbalance, these, he, venizelos, chippewa,
# Nearest to and: or, but, although, while, unsurprising, msp, shrewd, papa,
# Nearest to between: across, with, respectively, among, within, towards, varela, beyond,
# Nearest to use: stand, appear, reject, respond, provide, refer, apply, usage,
# Nearest to of: following, among, for, represents, besides, including, aerosmith, throughout,
# Nearest to more: less, rather, faster, fewer, greater, most, fairly, increasingly,
# Nearest to for: why, ago, of, without, throughout, during, after, following,
# Nearest to nine: eight, seven, five, raum, april, august, britannica, births,
# Nearest to such: well, opposed, follows, whole, viewed, result, long, described,
# Nearest to five: six, three, zero, eight, seven, nine, two, four,
# Nearest to with: between, through, unlike, among, thessalonians, while, amongst, regarding,
# Nearest to that: which, who, where, when, what, although, whether, whenever,
# Nearest to been: become, begun, fallen, occurred, survived, disappeared, existed, gone,
# Nearest to was: is, were, became, are, becomes, remains, makes, exists,
# Average loss at step 122000: 3.352752
# Average loss at step 124000: 3.215084
# Average loss at step 126000: 3.295497
# Average loss at step 128000: 3.302851
# Average loss at step 130000: 3.149687
# Nearest to i: g, traffickers, ii, unprotected, they, presumably, shu, who,
# Nearest to may: can, would, could, might, should, must, will, cannot,
# Nearest to they: we, you, organisms, he, these, others, frodo, i,
# Nearest to and: or, etc, but, meanwhile, however, cg, while, afb,
# Nearest to between: with, beyond, pondering, across, busing, against, varela, unacceptably,
# Nearest to use: exist, usage, form, apply, stand, provide, speak, conform,
# Nearest to of: across, in, for, locksmithing, besides, including, include, represents,
# Nearest to more: less, rather, faster, larger, most, fewer, smaller, stronger,
# Nearest to for: ago, when, besides, within, after, since, of, busan,
# Nearest to nine: eight, seven, six, four, mcfarland, utter, nicosia, edif,
# Nearest to such: well, follows, viewed, classified, result, interpreted, regarded, described,
# Nearest to five: six, four, eight, three, seven, zero, million, padua,
# Nearest to with: between, against, without, through, towards, unlike, unsolicited, regarding,
# Nearest to that: which, where, when, whereas, if, whose, additionally, unless,
# Nearest to been: become, begun, fallen, grown, come, existed, gone, happened,
# Nearest to was: is, were, became, becomes, are, makes, remains, had,
# Average loss at step 132000: 3.219772
# Average loss at step 134000: 3.160677
# Average loss at step 136000: 3.198780
# Average loss at step 138000: 3.216795
# Average loss at step 140000: 3.089379
# Nearest to i: g, you, nemo, inline, we, gen, l, cube,
# Nearest to may: could, can, might, would, must, will, should, cannot,
# Nearest to they: we, you, counterbalance, banaba, he, citizens, those, underdogs,
# Nearest to and: or, while, meanwhile, but, whilst, including, tenacious, quays,
# Nearest to between: across, with, beyond, throughout, unacceptably, respectively, among, pondering,
# Nearest to use: availability, protection, adoption, appointment, butte, allegiance, helper, benefit,
# Nearest to of: following, among, involving, in, versus, against, throughout, regarding,
# Nearest to more: less, rather, greater, faster, most, smaller, fewer, better,
# Nearest to for: after, following, ago, within, during, despite, besides, before,
# Nearest to nine: eight, six, seven, mcfarland, hutch, ufc, raum, retrospect,
# Nearest to such: well, follows, opposed, viewed, described, classified, known, far,
# Nearest to five: zero, six, three, four, eight, two, seven, luz,
# Nearest to with: between, against, without, involving, plus, giving, onto, among,
# Nearest to that: which, when, where, if, this, unless, whatever, whose,
# Nearest to been: become, begun, fallen, grown, disappeared, evolved, occurred, gone,
# Nearest to was: is, were, are, became, has, had, remains, makes,
# Average loss at step 142000: 3.145409
# Average loss at step 144000: 3.164367
# Average loss at step 146000: 2.957476
# Average loss at step 148000: 2.839011
# Average loss at step 150000: 3.064392
# Nearest to i: we, ii, you, they, g, mail, necropolis, gunn,
# Nearest to may: can, should, might, could, must, would, will, cannot,
# Nearest to they: we, you, he, she, previously, these, i, frodo,
# Nearest to and: or, while, whereas, but, however, meanwhile, including, whilst,
# Nearest to between: across, with, throughout, among, respectively, into, in, concerning,
# Nearest to use: apply, form, usage, support, disclose, conform, origin, migrated,
# Nearest to of: within, throughout, including, toward, for, among, in, involving,
# Nearest to more: less, rather, larger, greater, fewer, faster, stronger, most,
# Nearest to for: after, of, spent, despite, within, hrvatska, at, ago,
# Nearest to nine: eight, seven, six, five, mcfarland, britannica, four, antigonus,
# Nearest to such: well, viewed, follows, classified, result, far, regarded, described,
# Nearest to five: six, seven, three, eight, four, nine, june, july,
# Nearest to with: without, between, involving, against, by, plus, petropavlovsk, sudanese,
# Nearest to that: which, when, if, unless, because, who, whose, whether,
# Nearest to been: fallen, grown, become, begun, gone, occurred, come, happened,
# Nearest to was: is, became, are, were, remained, had, makes, exists,
# Average loss at step 152000: 3.090726
# Average loss at step 154000: 3.146773
# Average loss at step 156000: 3.146823
# Average loss at step 158000: 2.983826
# Average loss at step 160000: 3.098970
# Nearest to i: we, you, g, they, ii, mail, nemo, battlefields,
# Nearest to may: must, might, could, can, would, will, should, cannot,
# Nearest to they: we, you, i, he, she, these, frodo, follows,
# Nearest to and: but, whereas, while, or, etc, though, tenacious, llu,
# Nearest to between: beyond, across, with, throughout, respectively, in, unacceptably, concerning,
# Nearest to use: support, develop, development, used, manipulate, apply, perform, presence,
# Nearest to of: following, among, in, throughout, surrounding, for, including, locksmithing,
# Nearest to more: less, rather, faster, fewer, fairly, slower, most, larger,
# Nearest to for: including, amongst, after, tractates, over, of, by, why,
# Nearest to nine: eight, seven, six, mcfarland, minotaur, britannica, althea, psychotherapy,
# Nearest to such: well, far, follows, classified, regarded, viewed, acted, described,
# Nearest to five: four, three, six, zero, seven, eight, unselfish, two,
# Nearest to with: without, between, involving, through, firenze, by, mould, unsolicited,
# Nearest to that: which, what, how, if, where, whatever, who, when,
# Nearest to been: begun, become, fallen, grown, occurred, disappeared, happened, arisen,
# Nearest to was: is, were, became, are, makes, exists, remains, had,
# Average loss at step 162000: 3.106508
# Average loss at step 164000: 3.152607
# Average loss at step 166000: 2.918052
# Average loss at step 168000: 3.013742
# Average loss at step 170000: 3.001393
# Nearest to i: ii, mail, we, you, g, they, iv, penderecki,
# Nearest to may: might, will, could, can, must, would, should, shall,
# Nearest to they: we, you, he, she, couples, frodo, i, laban,
# Nearest to and: or, whereas, while, who, but, because, whilst, unsurprising,
# Nearest to between: with, across, through, within, among, beyond, into, in,
# Nearest to use: referring, detect, used, appear, return, refer, wait, change,
# Nearest to of: surrounding, throughout, following, leaving, including, among, represent, for,
# Nearest to more: less, rather, faster, smaller, fewer, better, greater, larger,
# Nearest to for: after, before, including, following, spent, over, within, ago,
# Nearest to nine: eight, seven, six, five, four, mcfarland, edif, stadler,
# Nearest to such: well, follows, regarded, far, viewed, described, classified, seen,
# Nearest to five: four, six, seven, eight, three, two, nine, herbicide,
# Nearest to with: between, by, without, against, through, using, including, involving,
# Nearest to that: which, unless, where, who, because, however, whatever, though,
# Nearest to been: become, fallen, begun, occurred, existed, grown, arisen, disappeared,
# Nearest to was: is, became, were, are, had, exists, makes, produces,
# Average loss at step 172000: 3.141456
# Average loss at step 174000: 3.020964
# Average loss at step 176000: 3.118777
# Average loss at step 178000: 3.102379
# Average loss at step 180000: 3.101186
# Nearest to i: ii, g, oops, nemo, fascists, we, pyrrhus, they,
# Nearest to may: would, can, might, must, could, cannot, will, should,
# Nearest to they: we, you, frodo, he, these, those, bipm, banaba,
# Nearest to and: while, but, or, etc, whereas, whilst, tenacious, meanwhile,
# Nearest to between: with, among, from, both, into, in, over, respectively,
# Nearest to use: usage, sense, appear, kind, existence, consist, dua, development,
# Nearest to of: following, among, throughout, for, thereof, mailing, notably, etc,
# Nearest to more: less, rather, faster, greater, fewer, larger, stronger, smaller,
# Nearest to for: after, following, within, before, why, of, hrvatska, ago,
# Nearest to nine: eight, seven, six, britannica, curium, vs, regimental, edif,
# Nearest to such: well, follows, interpreted, classified, result, described, seen, regarded,
# Nearest to five: four, zero, three, seven, six, two, fifteen, montoya,
# Nearest to with: between, despite, among, producing, introduces, involving, using, including,
# Nearest to that: which, where, who, unless, when, how, because, if,
# Nearest to been: begun, become, fallen, existed, occurred, disappeared, arisen, gone,
# Nearest to was: is, became, were, are, becomes, exists, makes, produces,
# Average loss at step 182000: 3.037758
# Average loss at step 184000: 3.037569
# Average loss at step 186000: 3.024775
# Average loss at step 188000: 3.050786
# Average loss at step 190000: 3.060044
# Nearest to i: g, ii, iii, we, mail, ministership, cold, copland,
# Nearest to may: can, might, must, would, could, should, cannot, will,
# Nearest to they: we, you, he, nicotine, these, she, fearsome, couples,
# Nearest to and: or, but, however, whereas, etc, meanwhile, whilst, while,
# Nearest to between: with, respectively, within, among, unacceptably, both, regarding, pondering,
# Nearest to use: usage, compete, develop, construction, support, preparation, presence, sense,
# Nearest to of: following, throughout, among, concerning, represents, for, representing, etc,
# Nearest to more: less, rather, greater, fewer, better, slower, faster, larger,
# Nearest to for: after, following, without, during, before, despite, ago, throughout,
# Nearest to nine: eight, britannica, seven, ethics, six, lsi, minotaur, virology,
# Nearest to such: well, far, described, classified, follows, regarded, seen, result,
# Nearest to five: four, three, six, seven, eight, zero, tenn, two,
# Nearest to with: between, involving, despite, regarding, including, holding, sudanese, petropavlovsk,
# Nearest to that: which, where, when, how, if, unless, whatever, moreover,
# Nearest to been: become, begun, fallen, gone, evolved, arisen, come, existed,
# Nearest to was: is, became, were, are, seemed, remained, gets, becomes,
# Average loss at step 192000: 3.080902
# Average loss at step 194000: 3.062764
# Average loss at step 196000: 2.930466
# Average loss at step 198000: 3.080786
# Average loss at step 200000: 3.090406
# Nearest to i: we, g, mail, you, undergone, berb, weezer, declines,
# Nearest to may: can, must, should, might, could, would, will, cannot,
# Nearest to they: you, we, he, couples, families, mojo, guin, she,
# Nearest to and: or, whereas, but, whilst, meanwhile, who, which, while,
# Nearest to between: with, respectively, beyond, among, through, regarding, otherwise, both,
# Nearest to use: form, usage, uses, manufacture, apply, production, sense, develop,
# Nearest to of: throughout, among, concerning, following, including, like, locksmithing, in,
# Nearest to more: less, rather, fewer, faster, most, stronger, slower, larger,
# Nearest to for: ago, after, following, hrvatska, suppose, over, why, during,
# Nearest to nine: eight, britannica, seven, abc, bucaram, entirely, six, himalaya,
# Nearest to such: well, follows, far, result, regarded, viewed, interpreted, classified,
# Nearest to five: four, six, three, seven, eight, two, zero, forty,
# Nearest to with: without, between, by, via, before, among, despite, involving,
# Nearest to that: which, where, how, whenever, this, what, thus, when,
# Nearest to been: become, gone, begun, fallen, occurred, arisen, existed, evolved,
# Nearest to was: is, were, became, are, remains, exists, becomes, had,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
